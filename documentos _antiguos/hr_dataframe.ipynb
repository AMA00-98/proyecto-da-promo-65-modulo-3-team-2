# %%
import pandas as pd

# %%
df_hr = pd.read_csv("hr.csv", index_col=0)

# %%
pd.set_option("display.max_columns", None)

# %%
df_hr
# Out:
#      Attrition     BusinessTravel  DailyRate              Department  \
# Age
# 41.0       Yes      Travel_Rarely       1102                   Sales
# 49.0        No  Travel_Frequently        279  Research & Development
# 37.0       Yes      Travel_Rarely       1373  Research & Development
# 33.0        No  Travel_Frequently       1392  Research & Development
# 27.0        No      Travel_Rarely        591  Research & Development
# ...        ...                ...        ...                     ...
# 34.0        No      Travel_Rarely        628  Research & Development
# 28.0        No      Travel_Rarely        866                   Sales
# 53.0        No      Travel_Rarely       1084  Research & Development
# 24.0       Yes      Travel_Rarely        240         Human Resources
# 45.0        No      Travel_Rarely       1339  Research & Development
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# Age
# ...

# %%
df_hr.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1474 entries, 41.0 to 45.0
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition                 1474 non-null   str
#  1   BusinessTravel            1357 non-null   str
#  2   DailyRate                 1474 non-null   int64
#  3   Department                1445 non-null   str
#  4   DistanceFromHome          1474 non-null   int64
#  5   Education                 1474 non-null   int64
#  6   EducationField            1416 non-null   str
#  7   EmployeeCount             1474 non-null   int64
#  8   EmployeeNumber            1474 non-null   int64
#  9   EnvironmentSatisfaction   1474 non-null   int64
#  10  Gender                    1474 non-null   str
#  11  HourlyRate                1474 non-null   int64
#  12  JobInvolvement            1474 non-null   int64
#  13  JobLevel                  1474 non-null   int64
# ...
